# %% [markdown]
# <a href="https://colab.research.google.com/github/pedroabn/portfolio/blob/Geral/python/leituraPDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Baixar pacote externo

# %%
# !pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.7-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.4 MB/s eta 0:00:00
# Collecting pdfminer.six==20250506 (from pdfplumber)
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.11/dist-packages (from pdfplumber) (11.2.1)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250506->pdfplumber) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250506->pdfplumber) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.22)
# Downloading pdfplumber-0.11.7-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.3 MB/s eta 0:00:00
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 21.8 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 24.0 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20250506 pdfplumber-0.11.7 pypdfium2-4.30.1

# %% [markdown]
# Baixa os pacotes para realizar as atividades

# %%
import pdfplumber as pp
import re
from google.colab import drive,files
from os.path import split
import os
import pandas as pd
import numpy as np

# %% [markdown]
# Acesso ao drive do Google

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Retornar os PDFs vistos dentro da pasta do Drive

# %%
id_pdf = ["/content/drive/MyDrive/ltdoc/1.pdf",
          "/content/drive/MyDrive/ltdoc/2.pdf","/content/drive/MyDrive/ltdoc/3.pdf",
          "/content/drive/MyDrive/ltdoc/4.pdf","/content/drive/MyDrive/ltdoc/5.pdf",
          "/content/drive/MyDrive/ltdoc/6.pdf","/content/drive/MyDrive/ltdoc/7.pdf",
          "/content/drive/MyDrive/ltdoc/8.pdf","/content/drive/MyDrive/ltdoc/9.pdf",
          "/content/drive/MyDrive/ltdoc/10.pdf","/content/drive/MyDrive/ltdoc/11.pdf",
          "/content/drive/MyDrive/ltdoc/12.pdf","/content/drive/MyDrive/ltdoc/13.pdf",
          "/content/drive/MyDrive/ltdoc/14.pdf","/content/drive/MyDrive/ltdoc/15.pdf",
          "/content/drive/MyDrive/ltdoc/16.pdf","/content/drive/MyDrive/ltdoc/18.pdf",
          "/content/drive/MyDrive/ltdoc/19.pdf","/content/drive/MyDrive/ltdoc/20.pdf",
          "/content/drive/MyDrive/ltdoc/21.pdf","/content/drive/MyDrive/ltdoc/22.pdf",
          "/content/drive/MyDrive/ltdoc/23.pdf","/content/drive/MyDrive/ltdoc/24.pdf",
          "/content/drive/MyDrive/ltdoc/25.pdf","/content/drive/MyDrive/ltdoc/26.pdf",
          "/content/drive/MyDrive/ltdoc/27.pdf","/content/drive/MyDrive/ltdoc/28.pdf",
          ]

# %% [markdown]
# Leitura do nome do projeto

# %%
def ler_nome(caminho_pdf):
#Usa a lib para abrir o pdf, o qual possui o caminho definido na célula de cima
# e lê as primeiras páginas em busca do objeto do projeto
  with pp.open(caminho_pdf) as pdf:
        page = pdf.pages[0]
        text = page.extract_text()
        linhas = text.split('\n')
  for linha in linhas:
    if re.search(r'\bNome\b', linha, re.IGNORECASE):
      nome = re.search(r'Nome do Projeto\s*[:\-]?\s*(.+)', text, re.IGNORECASE)
      if nome:
        return nome.group(1).strip()

  else:
        print("❌ Padrão não encontrado.")
        return None

# %% [markdown]
# Teste da def

# %%
j = "/content/drive/MyDrive/ltdoc/13.pdf"
print(ler_nome(j))

# %% [markdown]
# Leitura do resumo do projeto

# %%
def ler_objetivo(caminho_pdf):
#Usa a lib para abrir o pdf, o qual possui o caminho definido na célula de cima
# e lê as 3 primeiras páginas em busca do objeto do projeto
  with pp.open(caminho_pdf) as pdf:
        page = pdf.pages[0-5]
        text = ""
        for i in range(5):
            if i < len(pdf.pages):
                page = pdf.pages[i]
                text += page.extract_text()
        linhas = text.split('\n')
#Lê linha por linha do Objeto do projeto até objetivo geral
  for linha in linhas:
    obj = re.search(
        r'Objeto do Projeto[:\-]?\s*(.*?)\s*Objetivo Geral\s*[:\-]?',
        text,re.DOTALL)
    if obj:
        objetivo = obj.group(1).strip()
        return objetivo
  else:
        print("❌ Padrão não encontrado.")
        return None

# %% [markdown]
# Teste da def

# %%
j = "/content/drive/MyDrive/ltdoc/13.pdf"
print(ler_objetivo(j))
# Out:
# (Descrição do projeto):
# Realização da pré-produção e produção do longa-metragem "Os Guerreiros da Rua”, que terá 80 minutos, e aborda o
# cotidiano de crianças da periferia do Recife que se juntam para criar suas próprias aventuras.
# * O desenvolvimento do filme já foi feito, financiado pelo Funcultura 2017-18 quando o diretor Erickson Marinho aprovou
# o projeto na linha de roteiro.
# Página 1 de 6** Por causa do teto orçamentário deste edital, optamos por buscar o financiamento da pós-produção em outros editais,
# após a conclusão das filmagens.

# %% [markdown]
# Leitura de subdivisão do audiovisual

# %%
def ler_subdivisao(objetivo):
    #Criação de um dicionário para retornar os valores padronizados
  termos = {
        "Curta metragem": ["curta metragem", "curta-metragem"],
        "Média metragem": ["média metragem", "média-metragem","media metragem"],
        "Longa metragem": ["longa metragem", "longa-metragem","série","obra seriada"],
        "Oficina": ["oficina","formação","ensinar"],
        "Programações e ações": ["evento","concurso"],
        "Difusão": ["festival","mostra de cinema","sessões"],
        "Documentário": ["documentário","documental"],
        "Desenvolvimento": ["pós-produção","pré-produção","composição",
                            "desenvolver roteiro","desenvolver projeto"],
        "Animação": ["animação","desenhho"],
        "Memória e Preservação":["acervo","catalogação","catalogar","conservar"]}
    #Se há leitura de um objetivo geral, ele irá retornar tudo em minúsculo para
    #evitar qualquer dificuldade de leitura
  if objetivo:
    ol = objetivo.lower()
  else:
    return ""
    #Criar um dicionário para identificar posição e as categorias vistas,
    #retornando o primeiro termo. A escolha do primeiro termo, é devido a repeti
    #ção dos termos e buscando objetividade da escolha.
  posicoes = {}
  for categoria, variacoes in termos.items():
        for var in variacoes:
            pos = ol.find(var)
            if pos != -1:
                if categoria not in posicoes or pos < posicoes[categoria]:
                    posicoes[categoria] = pos
  if posicoes:
        if posicoes:
          ordenados = sorted(posicoes.items(), key=lambda x: x[1])  # ordena por posição
          dp = [item[0] for item in ordenados[:2]]  # pega os dois primeiros
          if len(dp) == 2:
            return dp[0], dp[1]
          elif len(dp) == 1:
            return dp[0], None
          else:
            return None, None
  else:
        return None

# %% [markdown]
# Teste da def

# %%
j = "/content/drive/MyDrive/ltdoc/7.pdf"
print(ler_subdivisao(ler_objetivo(j)))
# Out:
# ('Documentário', None)

# %% [markdown]
# Criação de uma tabela, com retorno das defs em colunas para analisar e fazer o join com a planilha do SIC

# %%
dados = []
for caminho_pdf in id_pdf:
  try:
      print(f"Lendo arquivo: {caminho_pdf}")
      aqvname = os.path.basename(caminho_pdf)
      pdfnome = ler_nome(caminho_pdf)
      print(f"Nome extraído: {pdfnome}")
      pdfobjetivo = ler_objetivo(caminho_pdf)
      objetivo = pdfobjetivo
      pdfsubdivisao = ler_subdivisao(objetivo)
      print(f"Subdivisão extraída: {pdfsubdivisao}")
      dados.append({
        "arquivo": aqvname,
        "nome": pdfnome if pdfnome else "",
        "objetivo": pdfobjetivo if pdfobjetivo else "",
        "subdivisao":pdfsubdivisao })
  except Exception as e:
      print(f"Erro ao processar o arquivo {caminho_pdf}: {e}")
# Out:
# Lendo arquivo: /content/drive/MyDrive/ltdoc/1.pdf
# Nome extraído: FICCIONALIZAR NA MATA
# Subdivisão extraída: ('Oficina', 'Documentário')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/2.pdf
# Nome extraído: OS PIONEIROS DA AVIAÇÃO
# Subdivisão extraída: ('Longa metragem', 'Documentário')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/3.pdf
# Nome extraído: OS GUERREIROS DA RUA – O FILME
# Subdivisão extraída: ('Desenvolvimento', 'Longa metragem')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/4.pdf
# Nome extraído: Herdeiros do Silêncio: Capital, Tráfico e Poder no Recife Oitocentista
# Subdivisão extraída: ('Documentário', 'Memória e Preservação')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/5.pdf
# Nome extraído: Distribuição do longa-metragem Armorialma
# Subdivisão extraída: ('Longa metragem', 'Documentário')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/6.pdf
# Nome extraído: DENTRO DA ESCURIDÃO
# Subdivisão extraída: ('Desenvolvimento', 'Longa metragem')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/7.pdf
# Nome extraído: De Dunquerque a Olinda: a Loucura do Carnaval” (doc)
# Subdivisão extraída: ('Documentário', None)
# Lendo arquivo: /content/drive/MyDrive/ltdoc/8.pdf
# Nome extraído: CIRCO DO SÓ EU. SINAL VERMELHO É PICADEIRO.
# Subdivisão extraída: ('Média metragem', None)
# Lendo arquivo: /content/drive/MyDrive/ltdoc/9.pdf
# Nome extraído: CAMISA 10 CUECA 0
# Subdivisão extraída: ('Curta metragem', 'Difusão')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/10.pdf
# Nome extraído: BAQUAQUA
# Subdivisão extraída: ('Longa metragem', 'Documentário')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/11.pdf
# Nome extraído: VÍDEO TRANSFORMAÇÃO 2.0
# Subdivisão extraída: ('Oficina', None)
# Lendo arquivo: /content/drive/MyDrive/ltdoc/12.pdf
# Nome extraído: Trocador
# Subdivisão extraída: ('Curta metragem', None)
# Lendo arquivo: /content/drive/MyDrive/ltdoc/13.pdf
# Nome extraído: TACO CLUBE PRAIANO - E O ASSALTO AO COLÉGIO CENTRAL
# Subdivisão extraída: ('Desenvolvimento', 'Longa metragem')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/14.pdf
# Nome extraído: Raízes do Hip Hop: Vozes e Resistência em Pernambuco
# Subdivisão extraída: ('Documentário', 'Oficina')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/15.pdf
# Nome extraído: Plano Conjunto – Laboratório de Cinema, Educação e Acessibilidade (2ª Edição)
# Subdivisão extraída: ('Difusão', 'Oficina')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/16.pdf
# Nome extraído: O VALE
# Erro ao processar o arquivo /content/drive/MyDrive/ltdoc/16.pdf: list index out of range
# Lendo arquivo: /content/drive/MyDrive/ltdoc/18.pdf
# Nome extraído: O Sonhário das Crianças
# Subdivisão extraída: ('Longa metragem', 'Documentário')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/19.pdf
# Nome extraído: Nariz Azul
# Subdivisão extraída: ('Curta metragem', 'Animação')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/20.pdf
# Nome extraído: Mostra Cine Rua: ano 3
# ❌ Padrão não encontrado.
# Subdivisão extraída:
# Lendo arquivo: /content/drive/MyDrive/ltdoc/21.pdf
# Nome extraído: Me Ensinaram Tudo Errado
# ❌ Padrão não encontrado.
# Subdivisão extraída:
# Lendo arquivo: /content/drive/MyDrive/ltdoc/22.pdf
# Nome extraído: Manifexxta – gravação dos videoclipes Jah Amor e Mangue
# Subdivisão extraída: ('Longa metragem', 'Desenvolvimento')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/23.pdf
# Nome extraído: Distribuição Recife Assombrado 2
# Subdivisão extraída: ('Longa metragem', None)
# Lendo arquivo: /content/drive/MyDrive/ltdoc/24.pdf
# Nome extraído: Cuma é o Nome Dele?
# Subdivisão extraída: ('Documentário', None)
# Lendo arquivo: /content/drive/MyDrive/ltdoc/25.pdf
# Nome extraído: Chá de Calcinha
# Subdivisão extraída: ('Curta metragem', None)
# Lendo arquivo: /content/drive/MyDrive/ltdoc/26.pdf
# Nome extraído: AZUL MARINHO - FINALIZAÇÃO
# Subdivisão extraída: ('Longa metragem', 'Desenvolvimento')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/27.pdf
# Nome extraído: ANIMAGE - 15º Festival Internacional de Animação de Pernambuco
# Subdivisão extraída: ('Difusão', 'Animação')
# Lendo arquivo: /content/drive/MyDrive/ltdoc/28.pdf
# Nome extraído: TRELA AUDIOVISUAL - ESCOLA DE CINEMA
# Subdivisão extraída: ('Oficina', 'Difusão')

# %%
df = pd.DataFrame(dados)
print(f"\n Arquivo {dados} processado com sucesso.")
# Out:
#  Arquivo [{'arquivo': '1.pdf', 'nome': 'FICCIONALIZAR NA MATA', 'objetivo': '(Descrição do projeto):\nCurso de formação em audiovisual “Ficcionalizar na Mata” é uma parceria do Coletivo Ficcionalizar e\ndo Coletivo Artístico e Ecopedagógico Boi da Mata, voltado para jovens e adolescentes da RPA4, que\nreúne os bairros da Caxangá, Cordeiro, Zumbi, Cidade universitária, Engenho do meio, Iputinga, Ilha\ndo Retiro, Madalena, Prado, Torre, Torrões, Várzea e UR7 Várzea. O curso é gratuito e destinado a 40\npessoas – jovens e adolescentes, a partir de 15 anos, e adultas de todas as idades. Terá o total de 141\nhoras/aulas, com oficinas de mapeamento cultural/ecológico, roteiro, direção, preparação de elenco,\nfotografia, som, edição, efeitos especiais e fotografia, acumuladas em duas etapas do processo de\nformação: a primeira, o módulo CONTAR, que abordará o gênero documentário, e a segunda, o\nmódulo RECONTAR E ENCANTAR, cujo gênero a ser abordado será o docficção. Neste iremos explorar\nas possibilidades de ficcionalização da realidade, abordando o tema principal desta edição do curso,\necopedagogia, cultura popular e ancestral. Cada módulo terá conteúdo teórico e prático, que\nresultará em dois filmes, que serão finalizados com acessibilidade (lse e audiodescrição) e serão\ndivulgados gratuitamente nas redes sociais e canal de youtube do Ficcionalizar, bem como se fará a\nsua exibição na UR7- Várzea, com o envolvimento de toda a comunidade, a partir da divulgação direta\nda rádio comunitária da UR7- Várzea, cartazes espalhados na comunidade, redes sociais, imprensa e\no “boca a boca”.\nPágina 1 de 5', 'subdivisao': ('Oficina', 'Documentário')}, {'arquivo': '2.pdf', 'nome': 'OS PIONEIROS DA AVIAÇÃO', 'objetivo': '(Descrição do projeto):\nRealização de série documental sobre os pioneiros da aviação no Brasil com 05 episódios de 26’.', 'subdivisao': ('Longa metragem', 'Documentário')}, {'arquivo': '3.pdf', 'nome': 'OS GUERREIROS DA RUA – O FILME', 'objetivo': '(Descrição do projeto):\nRealização da pré-produção e produção do longa-metragem "Os Guerreiros da Rua”, que terá 80 minutos, e aborda o\ncotidiano de crianças da periferia do Recife que se juntam para criar suas próprias aventuras.\n* O desenvolvimento do filme já foi feito, financiado pelo Funcultura 2017-18 quando o diretor Erickson Marinho aprovou\no projeto na linha de roteiro.\nPágina 1 de 6** Por causa do teto orçamentário deste edital, optamos por buscar o financiamento da pós-produção em outros editais,\napós a conclusão das filmagens.', 'subdivisao': ('Desenvolvimento', 'Longa metragem')}, {'arquivo': '4.pdf', 'nome': 'Herdeiros do Silêncio: Capital, Tráfico e Poder no Recife Oitocentista', 'objetivo': '(Descrição do projeto):\nObjeto do Projeto (Descrição do projeto):\nO documentário Herdeiros do Silêncio: Capital, Tráfico e Poder no Recife Oitocentista mergulha na complexa e pouco\ndebatida relação entre o tráfico de escravizados no século XIX e a consolidação das elites econômicas e políticas de\nPernambuco. A produção é conduzida pela historiadora e protagonista Amanda Barlavento, que, a partir de sua\npesquisa acadêmica, percorre o Recife e arredores em busca de vestígios desse passado, desvendando como fortunas\nconstruídas sobre a escravidão foram convertidas em poder e influência, perpetuando desigualdades que ainda\nmoldam a sociedade brasileira.\nO ponto de partida da investigação é a trajetória de Augusto Frederico de Oliveira, herdeiro de uma das mais\nexpressivas fortunas geradas pelo tráfico transatlântico de seres humanos, e sua ascensão como banqueiro,\nempresário e figura política no Brasil Imperial. Através de visitas a acervos históricos, arquivos públicos e centros de\npesquisa, o documentário reconstroi o impacto dessa rede econômica, ao mesmo tempo em que promove um diálogo\ncom historiadores, antropólogos, lideranças negras e comunidades afrodescendentes sobre as heranças desse sistema\nna atual configuração social de Recife.\nA abo ...

# %%
print(df.head())
# Out:
#   arquivo                                               nome  \
# 0   1.pdf                              FICCIONALIZAR NA MATA
# 1   2.pdf                            OS PIONEIROS DA AVIAÇÃO
# 2   3.pdf                     OS GUERREIROS DA RUA – O FILME
# 3   4.pdf  Herdeiros do Silêncio: Capital, Tráfico e Pode...
# 4   5.pdf          Distribuição do longa-metragem Armorialma
#
#                                             objetivo  \
# 0  (Descrição do projeto):\nCurso de formação em ...
# 1  (Descrição do projeto):\nRealização de série d...
# 2  (Descrição do projeto):\nRealização da pré-pro...
# 3  (Descrição do projeto):\nObjeto do Projeto (De...
# 4  (Descrição do projeto):\nVisa a distribuição d...
#
#                               subdivisao
# 0                (Oficina, Documentário)
# 1         (Longa metragem, Documentário)
# 2      (Desenvolvimento, Longa metragem)
# 3  (Documentário, Memória e Preservação)
# 4         (Longa metragem, Documentário)

# %%
# Separar cada resposta por vírgula e 'explodir' em várias linhas
subdivisao_count = (
    df['subdivisao']
    .astype(str)
    .str.replace(" ", "")
    .str.replace("(", "")
    .str.replace(")", "")
    .str.replace("'", "")
    .str.split(',')
    .explode()
    .str.replace("None", "", regex=False)  # remove todos os espaços
    .replace("", pd.NA)
    .str.strip()  # Remover espaços iniciais e no fim em branco
    .dropna()
    .reset_index(drop=True))
df = pd.concat([df, subdivisao_count], axis=1)
print(df.head())
# Out:
# Valores separados:
# 0                 Oficina
# 1            Documentário
# 2           Longametragem
# 3            Documentário
# 4         Desenvolvimento
# 5           Longametragem
# 6            Documentário
# 7     MemóriaePreservação
# 8           Longametragem
# 9            Documentário
# 10        Desenvolvimento
# 11          Longametragem
# 12           Documentário
# 13          Médiametragem
# 14          Curtametragem
# 15                Difusão
# 16          Longametragem
# 17           Documentário
# 18                Oficina
# 19          Curtametragem
# 20        Desenvolvimento
# 21          Longametragem
# 22           Documentário
# 23                Oficina
# 24                Difusão
# 25                Oficina
# 26          Longametragem
# 27           Documentário
# 28          Curtametragem
# 29               Animação
# 30          Longametragem
# 31        Desenvolvimento
# 32          Longametragem
# 33           Documentário
# 34          Curtametragem
# 35          Longametragem
# 36        Desenvolvimento
# 37                Difusão
# 38               Animação
# 39                Oficina
# 40                Difusão
# Name: subdivisao, dtype: object
#   arquivo                                               nome  \
# 0   1.pdf                              FICCIONALIZAR NA MATA
# 1   2.pdf                            OS PIONEIROS DA AVIAÇÃO
# 2   3.pdf                     OS GUERREIROS DA RUA – O FILME
# 3   4.pdf  Herdeiros do Silêncio: Capital, Tráfico e Pode...
# 4   5.pdf          Distribuição do longa-metragem Armorialma
#
#                                             objetivo  \
# 0  (Descrição do projeto):\nCurso de formação em ...
# 1  (Descrição do projeto):\nRealização de série d...
# 2  (Descrição do projeto):\nRealização da pré-pro...
# 3  (Descrição do projeto):\nObjeto do Projeto (De...
# 4  (Descrição do projeto):\nVisa a distribuição d...
#
#                               subdivisao       subdivisao
# 0                (Oficina, Documentário)          Oficina
# 1         (Longa metragem, Documentário)     Documentário
# 2      (Desenvolvimento, Longa metragem)    Longametragem
# 3  (Documentário, Memória e Preservação)     Documentário
# 4         (Longa metragem, Documentário)  Desenvolvimento

# %%
if dados:
    df.to_excel("Subdivisao.xlsx", index=False)
    print("✅ Subdivisao.xlsx salvo.")
else:
    print("⚠️ Nenhum dado encontrado.")

files.download("Subdivisao.xlsx")
# Out:
# ✅ Subdivisao.xlsx salvo.
